# %%
from bs4 import BeautifulSoup as BS
import requests
import pandas
import json
import time

def getData(url, city, job, pagenum, cookie):
#     print(cookie)
    headers = {
        "Accept": "application/json, text/javascript, */*; q=0.01",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "en,zh-CN;q=0.9,zh;q=0.8",
        "Connection": "keep-alive",
        "Content-Length": "129",
        "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
        "Host": "www.lagou.com",
        "Cookie": cookie,
        "Origin": "https://www.lagou.com",
        "Referer": "https://www.lagou.com/jobs/list_%E5%A4%A7%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90%E5%B7%A5%E7%A8%8B%E5%B8%88/p-city_2?&cl=false&fromSearch=true&labelWords=&suginput=",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "same-origin",
        "User-Agent": "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36",
        "X-Anit-Forge-Code": "0",
        "X-Anit-Forge-Token": "None",
        "X-Requested-With": "XMLHttpRequest"
        
    }
    params = {
        "city": city,
        "needAddtionalResult": "false"
    }
    data={
        'first':'false',
        'pn':pagenum,
        'kd':job,
    }
    r = requests.post(url, data=data, headers=headers)
    r.encoding = "utf-8"
    datas = r.json()
    print(datas)
    if "success"in datas:
#         print(datas)
        return datas
    else:
        print(datas)
        

def handle_datas(datas):
    pass


def main():
    url = "https://www.lagou.com/jobs/positionAjax.json?city=%E5%8C%97%E4%BA%AC&needAddtionalResult=false"
    city = "北京"
    job = "大数据分析"
#     cookie = "user_trace_token=20190917154948-3ec98cd0-9a8b-4030-a48a-730ebe79effa; _ga=GA1.2.1588227263.1568706590; LGUID=20190917154950-ba0d210d-d91f-11e9-92c1-525400f775ce; _gid=GA1.2.175410341.1568706607; index_location_city=%E5%8C%97%E4%BA%AC; JSESSIONID=ABAAABAAAGFABEF02B657F7B33B24EB87256E0B367D3619; WEBTJ-ID=20190917172015-16d3e85bf85519-025737173798b3-4f4f082e-1049088-16d3e85bf86713; Hm_lvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1568712010,1568712016,1568712282,1568712287; X_MIDDLE_TOKEN=866054a7aee3468ade4d6da3a90ae3be; TG-TRACK-CODE=search_code; LGSID=20190917185314-59177894-d939-11e9-a51a-5254005c3644; SEARCH_ID=227a31af68c24baa96b4a7944ef824a1; X_HTTP_TOKEN=e5d71303e3748fd13580278651eb2e7203194f4ad1; _gat=1; LGRID=20190917194733-efa3c048-d940-11e9-a51a-5254005c3644; Hm_lpvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1568720853"
    cookie = "user_trace_token=20190917154948-3ec98cd0-9a8b-4030-a48a-730ebe79effa; _ga=GA1.2.1588227263.1568706590; LGUID=20190917154950-ba0d210d-d91f-11e9-92c1-525400f775ce; _gid=GA1.2.175410341.1568706607; index_location_city=%E5%8C%97%E4%BA%AC; JSESSIONID=ABAAABAAAGFABEF02B657F7B33B24EB87256E0B367D3619; WEBTJ-ID=20190917172015-16d3e85bf85519-025737173798b3-4f4f082e-1049088-16d3e85bf86713; X_MIDDLE_TOKEN=866054a7aee3468ade4d6da3a90ae3be; _gat=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2216d3f0f3215c2-0f2f728052f1b6-4f4f082e-1049088-16d3f0f321921%22%2C%22%24device_id%22%3A%2216d3f0f3215c2-0f2f728052f1b6-4f4f082e-1049088-16d3f0f321921%22%7D; sajssdk_2015_cross_new_user=1; LGSID=20190917195059-6a491ee7-d941-11e9-92e9-525400f775ce; PRE_UTM=; PRE_HOST=www.baidu.com; PRE_SITE=http%3A%2F%2Fwww.baidu.com%2Flink%3Furl%3DNYdt0VgX5DRsI2DIU8F8HszBPrmnV1hWYK4scuyakDqAd0AENEPJB0vs0YcHAjbQ%26wd%3D%26eqid%3Da3728ea4000b1d52000000025d80c89d; PRE_LAND=https%3A%2F%2Fwww.lagou.com%2Fzhaopin%2F; Hm_lvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1568712282,1568712287,1568721059,1568721112; TG-TRACK-CODE=index_search; gate_login_token=4e6e03dde666c7a6fa6ca3e5a2e7855de13abc798d3cbbeb; _putrc=1DBEF72B50CC8209; login=true; unick=%E6%9D%8E%E5%85%83%E7%A3%8A; privacyPolicyPopup=false; showExpriedIndex=1; showExpriedCompanyHome=1; showExpriedMyPublish=1; hasDeliver=0; SEARCH_ID=d1a7367fffa24b258d8dc6b88d880de9; X_HTTP_TOKEN=e5d71303e3748fd14521278651eb2e7203194f4ad1; LGRID=20190917195415-df12450a-d941-11e9-92e9-525400f775ce; Hm_lpvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1568721255"
    for pagenum in range(1,18):
        getData(url, city, job, pagenum, cookie)
        time.sleep(2)

if __name__ == '__main__':
    main()
# Out:
# {'msg': None, 'requestId': None, 'resubmitToken': None, 'success': True, 'code': 0, 'content': {'showId': '0c4d60932dfc474a9c2ed9c8f4eb2ef6', 'hrInfoMap': {'6107549': {'userId': 5966600, 'positionName': '师资发展中心', 'portrait': 'i/image2/M01/1E/E7/CgoB5ly5lXCAYY_gAAEyWcgsG4g948.jpg', 'phone': None, 'receiveEmail': None, 'canTalk': True, 'userLevel': 'G1', 'realName': '薛姣'}, '6128476': {'userId': 4981135, 'positionName': 'HRM', 'portrait': 'i/image2/M01/57/DC/CgotOVsg11mAeDf5AAAKF-tHNPA537.png', 'phone': None, 'receiveEmail': None, 'canTalk': True, 'userLevel': 'G1', 'realName': 'LinkedME'}, '5883451': {'userId': 11119819, 'positionName': 'HR', 'portrait': 'i/image2/M01/7C/2B/CgotOV1eqhyAN25OAAHCBeX5ihc96.jpeg', 'phone': None, 'receiveEmail': None, 'canTalk': True, 'userLevel': 'G1', 'realName': 'Jessie'}, '6284476': {'userId': 12083577, 'positionName': '招聘经理', 'portrait': 'i/image2/M01/C5/81/CgoB5lwy__uAXZCiAABSGJg04EA466.png', 'phone': None, 'receiveEmail': None, 'canTalk': True, 'user
# ...
